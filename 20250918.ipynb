# %% [markdown]
# ##2025-09-18

# %%
print("Hello, UGLY!")
# Out:
# Hello, UGLY!

# %%
print("Hell")
# Out:
# Hell

# %%
print("안녕하신가 껄껄")
# Out:
# 안녕하신가 껄껄

# %%
print("아니 왜 안뜨냐고")
# Out:
# 아니 왜 안뜨냐고

# %% [markdown]
# ![image.png](attachment:image.png)
